# %%
import pandas as pd

# %%
df = pd.read_csv("/home/ctchervenkov/Documents/projects/sccer_ja/data/10_interim/features.txt", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-2efc3f1a9f69> in <module>
# ----> 1 df = pd.read_csv("/home/ctchervenkov/Documents/projects/sccer_ja/data/10_interim/features.txt", sep="\t")
#
# ~/.local/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df
# Out:
#        agentId\tlongest_stop_s\tlongest_stop_9_16_s\tlongest_trip_m\ttotal_stop_s\ttotal_trip_m\tparked_s_[0.0;900.0]\tdistance_m_[0.0;900.0]\tparked_s_[900.0;1800.0]\tdistance_m_[900.0;1800.0]\tparked_s_[1800.0;2700.0]\tdistance_m_[1800.0;2700.0]\tparked_s_[2700.0;3600.0]\tdistance_m_[2700.0;3600.0]\tparked_s_[3600.0;4500.0]\tdistance_m_[3600.0;4500.0]\tparked_s_[4500.0;5400.0]\tdistance_m_[4500.0;5400.0]\tparked_s_[5400.0;6300.0]\tdistance_m_[5400.0;6300.0]\tparked_s_[6300.0;7200.0]\tdistance_m_[6300.0;7200.0]\tparked_s_[7200.0;8100.0]\tdistance_m_[7200.0;8100.0]\tparked_s_[8100.0;9000.0]\tdistance_m_[8100.0;9000.0]\tparked_s_[9000.0;9900.0]\tdistance_m_[9000.0;9900.0]\tparked_s_[9900.0;10800.0]\tdistance_m_[9900.0;10800.0]\tparked_s_[10800.0;11700.0]\tdistance_m_[10800.0;11700.0]\tparked_s_[11700.0;12600.0]\tdistance_m_[11700.0;12600.0]\tparked_s_[12600.0;13500.0]\tdistance_m_[12600.0;13500.0]\tparked_s_[13500.0;14400.0]\tdistance_m_[13500.0;14400.0]\tparked_s_[14400.0;15300.0]\td
# ...
